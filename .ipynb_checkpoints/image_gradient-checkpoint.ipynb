# %%
from matplotlib import pyplot as plt
from scipy import signal
import math
import numpy as np

# %%
def calculate_gradient_image(img):
    #partial x
    gradient_img_x = np.zeros(img.shape)
    kernel = np.array([[1, 0, -1], [2, 0, -2], [1, 0, -1]])
    for i in range(3):
        gradient_img_x[:, :, i] = signal.convolve(img[:, :, i], kernel, mode = 'same')
    #partial y
    gradient_img_y = np.zeros(img.shape)
    kernel = np.array([[1, 2, 1], [0, 0, 0], [-1, -2, -1]])
    for i in range(3):
        gradient_img_y[:, :, i] = signal.convolve(img[:, :, i], kernel, mode = 'same')
    #magnitute of gradient
    gradient_img = np.zeros(img.shape)
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            for c in range(img.shape[2]):
                gradient_img[i][j][c] =  int(math.sqrt((gradient_img_x[i][j][c]**2) \
                                                       + (gradient_img_y[i][j][c]**2)))
    return gradient_img

# %%
img = plt.imread("lena.bmp")
# for i in range(img.shape[0]):
#     for j in range(img.shape[1]):
#         for c in range(img.shape[2]):
#             partial_y = 0
#             partial_x = 0
#             if (j < img.shape[1] - 1):
#                 partial_y = int(img[i][j][c]) - int(img[i][j + 1][c])
#             else:
#                 partial_y = int(img[i][j][c])
#             #
#             if (i < img.shape[0] - 1):
#                 partial_x = int(img[i][j][c]) - int(img[i + 1][j][c])
#             else:
#                 partial_x = int(img[i][j][c])
#             partial_x = (partial_x // 2) + 128
#             partial_y = (partial_y // 2) + 128
#             gradient_img[i][j][c] = int(math.sqrt((partial_x**2) + (partial_y**2)))

plt.imshow(calculate_gradient_image(img))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
